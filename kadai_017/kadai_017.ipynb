# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def check_adult(self):
    if self.age >= 20:
      print(f"{self.name}は大人です。")
    else:
      print(f"{humans[i].name}は大人ではありません。")

human1 = Human("竹内伶", 27)
human2 = Human("竹内優那", 23)
human3 = Human("竹内蓮水", 5)
human4 = Human("竹内橙矢", 0)

humans = [human1, human2, human3, human4]

for human in humans:
  human.check_adult()
# Out:
# 竹内伶は大人です。
# 竹内優那は大人です。
# 竹内橙矢は大人ではありません。
# 竹内橙矢は大人ではありません。
