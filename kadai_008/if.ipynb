# %%
var = 15

if var % 3 == 0 or var % 5 == 0:
  if var % 3 == 0:
    print('Fizz')
  if var % 5 == 0:
    print('Buzz')
  if var % 3 == 0 and var % 5 == 0:
    print('FizzBuzz')
else:
  print(var)
# Out:
# 1
